# %% [markdown]
# # Mobile Robotics Project - Controlling Thymio
# The following report details how the Thymio robot was controlled through an obstacle filled course with sudden local obstacles added. A camera was implemented to create a map and track the position and orientation of the robot. These variables were then processed through a Kalman Filter combining odometry to output the necessary variables for a PID controller to direct the mobile robot.

# %%
# !pip install tqdm scipy
# Out:
# Requirement already satisfied: tqdm in c:\users\mmaqu\anaconda3\lib\site-packages (4.66.4)
# Requirement already satisfied: scipy in c:\users\mmaqu\anaconda3\lib\site-packages (1.13.1)
# Requirement already satisfied: colorama in c:\users\mmaqu\anaconda3\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: numpy<2.3,>=1.22.4 in c:\users\mmaqu\anaconda3\lib\site-packages (from scipy) (1.26.4)

# %%
#The exclamation point (!) allow to execute a terminal command in the notebook:
# !python -m tdmclient list

# %%
from tdmclient import ClientAsync
client = ClientAsync()
node = await client.wait_for_node()
await node.lock()
# Out:
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[3], line 3
#       1 from tdmclient import ClientAsync
#       2 client = ClientAsync()
# ----> 3 node = await client.wait_for_node()
#       4 await node.lock()
#
# File ~\anaconda3\Lib\site-packages\tdmclient\clientasync.py:106, in ClientAsync.wait_for_node(self, timeout, **kwargs)
#     104     sleep(self.DEFAULT_SLEEP)
#     105     time += self.DEFAULT_SLEEP
# --> 106 yield
#
# CancelledError:

# %% [markdown]
# ## 1. Vision Processing
# The vision system takes the images captured by the camera and locates the robot, obstacles, goal and start position.

# %% [markdown]
# ## 2. Global Navigation
# The A* algorithm was selected to create the ideal path for the robot to travel. The code for this algorithm was obtained from the solutions from the week 5 and modified to adapt the project specifications.

# %%
## Code from exercises week 5, modified A* algorithm, BoMR course

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from heapq import heappush, heappop # used if you want to use heap queue for priority queue (easier to implement) but not compulsory

def heuristic(a, b):
    # Implement the Euclidean distance heuristic
    return np.sqrt((a[0] - b[0])**2 + (a[1] - b[1])**2)

def in_grid(grid, pos):
    return 0 <= pos[0] < grid.shape[0] and 0 <= pos[1] < grid.shape[1]

def is_obstacle(grid, pos):
    return not in_grid(grid, pos) or (grid[pos] == -1)


# A* algorithm implementation in a Grid
def a_star_search(map_grid, start, goal):
    # Initialize the open set as a priority queue and add the start node
    open_set = []
    heappush(open_set, (heuristic(start, goal), 0, start))  # (f_cost, g_cost, position)

    # Initialize the came_from dictionary
    came_from = {}
    # Initialize g_costs dictionary with default value of infinity and set g_costs[start] = 0
    g_costs = {start: 0}
    # Initialize the explored set
    explored = set()
    operation_count = 0

    while open_set:
        # Pop the node with the lowest f_cost from the open set
        current_f_cost, current_g_cost, current_pos = heappop(open_set)

        # Add the current node to the explored set
        explored.add(current_pos)

        # For directly reconstruct path
        if current_pos == goal:
            break
        
        up         = (current_pos[0] - 1, current_pos[1]    )
        down       = (current_pos[0] + 1, current_pos[1]    )  # Down
        left       = (current_pos[0]    , current_pos[1] - 1)  # Left
        right      = (current_pos[0]    , current_pos[1] + 1)  # Right
        up_left    = (current_pos[0] - 1, current_pos[1] - 1)  # Up Left
        down_right = (current_pos[0] + 1, current_pos[1] + 1)  # Down Right
        down_left  = (current_pos[0] + 1, current_pos[1] - 1)  # Down Left
        up_right   = (current_pos[0] - 1, current_pos[1] + 1)   # Up Right
        # Get the neighbors of the current node (up, down, left, right)
        neighbors = [up, down, left, right, up_left, down_right, down_left, up_right]
        
        
        if is_obstacle(map_grid, up) or is_obstacle(map_grid, left) :
                neighbors.remove(up_left)
        
        if is_obstacle(map_grid, up) or is_obstacle(map_grid, right):
                neighbors.remove(up_right)
                
        if is_obstacle(map_grid, down) or is_obstacle(map_grid, right):
                neighbors.remove(down_right)
                
        if is_obstacle(map_grid, down) or is_obstacle(map_grid, left):
                neighbors.remove(down_left)
            
                
        for neighbor in neighbors:
            # Check if neighbor is within bounds and not an obstacle
            if (in_grid(map_grid,neighbor)) and map_grid[neighbor[0], neighbor[1]] != -1 and neighbor not in explored:
                # Calculate tentative_g_cost
                tentative_g_cost = current_g_cost + heuristic(current_pos, neighbor)
                
                # If this path to neighbor is better than any previous one
                if neighbor not in g_costs or tentative_g_cost < g_costs[neighbor]:
                    # Update came_from, g_costs, and f_cost
                    came_from[neighbor] = current_pos
                    g_costs[neighbor] = tentative_g_cost
                    f_cost = tentative_g_cost + heuristic(neighbor, goal)

                    # Add neighbor to open set
                    heappush(open_set, (f_cost, tentative_g_cost, neighbor))
                    operation_count += 1

    # Reconstruct path
    if current_pos == goal:
        path = []
        while current_pos in came_from:
            path.append(current_pos)
            current_pos = came_from[current_pos]
        path.append(start)
        return path[::-1], explored,operation_count
    else:
        # If we reach here, no path was found
        return None, explored,operation_count
    

    
    
# Function for the visualization of the Map, including the Path, Obstacles and explored positions.    
def display_map(map_grid, path, start, goal, explored):
    cmap = ListedColormap(['white', 'black', 'blue', 'green', 'red', 'grey'])
    map_display = np.zeros_like(map_grid, dtype=object)

    # Assign colors based on the map grid values
    map_display[map_grid == -1] = 'black'  # Obstacles
    map_display[map_grid == 0] = 'white'   # Free space

    for position in explored:
        if map_display[tuple(position)] == 'white':
            map_display[tuple(position)] = 'grey'  # Explored cells

    # Visualize the path
    for position in path:
        if map_display[position[0], position[1]] in ['white', 'grey']:
            map_display[position[0], position[1]] = 'blue'  # Path

    map_display[start[0], start[1]] = 'green'  # Start
    map_display[goal[0], goal[1]] = 'red'      # Goal

    # Convert color names to numbers for plotting
    color_mapping = {'white': 0, 'black': 1, 'blue': 2, 'green': 3, 'red': 4, 'grey': 5, 'yellow': 6}
    map_numeric_display = np.vectorize(color_mapping.get)(map_display)
    fig, ax = plt.subplots(figsize=(6, 7))
    ax.imshow(map_numeric_display, cmap=cmap)
    ax.set_xticks(np.arange(-0.5, map_grid.shape[1], 1), minor=True)
    ax.set_yticks(np.arange(-0.5, map_grid.shape[0], 1), minor=True)
    ax.grid(which='minor', color='gray', linestyle='-', linewidth=0.5)
    ax.tick_params(which='both', bottom=False, left=False, labelbottom=False, labelleft=False)
    ax.set_title('a_star_search Visualization')
    plt.show()

# Definition of Map Dimensions
map_height = 9
map_width = 6
Map = np.zeros((map_height, map_width))


# Definition of the obstacles
Map[8, 1] = -1; Map[6, 4:6] = -1; Map[4, 2:3] = -1; Map[3, 3] = -1; Map[1, 1] = -1; Map[2, 0] = -1


# Definition of Start ang Goal Positions
SearchStart = (8, 5)
SearchGoal  = (0, 0)


# Running A* Algorithm and extraction of the optimal path if it exists. (Optimal in the sense of lowest cost)
path, explored, operation_count = a_star_search(Map, SearchStart, SearchGoal)

# Display the result
if path:
    print("Path found:")
    print(path)
    print(f"Number of operations: {operation_count}")
    display_map(Map, path, SearchStart, SearchGoal, explored)
else:
    print("No path found.")
# Out:
# Path found:
# [(8, 5), (7, 4), (7, 3), (6, 2), (5, 1), (4, 1), (3, 1), (2, 2), (1, 2), (0, 2), (0, 1), (0, 0)]
# Number of operations: 53

# %% [markdown]
# With the most efficient path stored, the critical points, meaning changes in orientation, were stored in a new list that defined the goals for the controller. This list is produced by the following function.

# %%
# Takes the path found by the A* algorithm as an argument and removes the points with a repeated orientation

def goal_list_from_path(path):
    goal_list = path.copy()
    popped = 0
    for i in range(len(path)-2):
        # Checks if three consecutive points lie in a straiExght line and removes middle because it is redundant
        if (path[i+1][0] - path[i][0] == path[i+2][0] - path[i+1][0]) and (path[i+1][1] - path[i][1] == path[i+2][1] - path[i+1][1]):
            goal_list.pop(i+1 - popped)
            popped += 1
    return goal_list

goal_list = goal_list_from_path(path)

print("A* path:           ", path)
print("Reduced goal list: ", goal_list)
# Out:
# A* path:            [(8, 5), (7, 4), (7, 3), (6, 2), (5, 1), (4, 1), (3, 1), (2, 2), (1, 2), (0, 2), (0, 1), (0, 0)]
# Reduced goal list:  [(8, 5), (7, 4), (7, 3), (5, 1), (3, 1), (2, 2), (0, 2), (0, 0)]

# %% [markdown]
# ## 3. Local Navigation
# The local navigation relies on the horizontal sensors of the Thymio. If an object is detected, the robot changes the velocity of the motors to effectively avoid it. The motor velocity changes are made through the **weights**. Each weight determines how a sensor impacts the robots movement which is why the weights for each motor (output) are symmetric, but opposite in sign. In this way, when a sensor detects an obstacle the motors respond in a way that steer it away.
#
# The code can be seen as a single-layer neural network where the input is the proximity sensor (9 elements) and the output is each motor (2). Parts of the code were taken from the solutions to the third week exercises on Artificial Neural Networks.

# %%
## For testing functionality of the sensors

# Function was obtained from the solutions of the week 3 exercises covering artificial neural networks
async def print_sensor_values(sensor_id, print_range=2, delta_time=0.2):
    """
    Print the sensor value sensor_id print_range times, every delta_time seconds
    """
    await node.wait_for_variables({str(sensor_id)})
    for i in range(print_range):
        print(list(node[sensor_id]))
        await client.sleep(delta_time)
        
await print_sensor_values('prox.horizontal')
# Out:
# [2343, 2396, 2289, 0, 0, 0, 0]
# [2333, 2394, 2288, 0, 0, 0, 0]

# %%
## Function to obtain the sensor values from the selected type of sensors. Similar to function print_sensor_values obtained from solutions for week 3 exercises

async def get_sensor_values(sensor_id, delay=0.01):
    await client.sleep(delay)
    sensor_values = list(node[sensor_id])  # Retrieve the current values
    return sensor_values  # Return the collected sensor values as a list

horizontal_sensor_values = await get_sensor_values('prox.horizontal')

# %%
## Function to verify if there are any obstacles. Gets the current readings of the get_sensor_values function for the horizontal sensors
## If the value of the sensor is above the proximity threshold, it sends a 1

async def check_obstacles(proximity_threshold=2000):
    horizontal_sensor_values = await get_sensor_values('prox.horizontal')
    if any(x > proximity_threshold for x in horizontal_sensor_values):
        return 1  # Obstacle detected
    return 0  # No obstacle

# %%
## Function to avoid obstacles based on neural network
## Obtained from solutions for week 3 exercises and adapted to satisfy speed requirements and asynchronous functionality

async def obstacle_avoidance(left_output=0, right_output=0):
    # Define weights for left and right motors
    w_l = [40, 20, -20, -20, -40, 30, -10]
    w_r = [-40, -20, -20, 20, 40, -10, 30]

    # Scale factors for sensors and constant factor
    sensor_scale = 500
    
    # Read proximity sensor values
    prox_values = list(node['prox.horizontal'])
    
    # Compute motor outputs based on the scaled sensor values
    for i in range(len(prox_values)):
        # Scale the sensor readings
        scaled_value = prox_values[i] // sensor_scale
        
        # Update outputs for left and right motors
        left_output += scaled_value * w_l[i] // 3
        right_output += scaled_value * w_r[i] // 3

    # Set motor powers
    await node.set_variables(motors(left_output, right_output))
    print(f"Left Motor: {left_output}, Right Motor: {right_output}")
    
    return left_output, right_output

# %% [markdown]
# ## 4. Kalman Filter

# %% [markdown]
# ## 5. Motion Control

# %% [markdown]
# ### 5.1 PID Control
#
# To effectively create a controller to ensure the robot was able to follow the path, a PID controller based on the orientation error of the robot was employed. The orientation is obtained through the camera and processed with the Kalman filter to effectively control the robot. A series of functions were used to create the controller based on the error measured between the desired path and the actual measurements. The appropriate gains were selected after testing their effect and identifying the desired response for the robot. The following considerations were taken into account:
#
# #### Proportional Gain (\(k_p\))
# - Controls the strength of the robot's response to the current error.
# - Determines the time taken to correct the error (avoiding overshooting or overly slow responses).
#
# #### Integral Gain (\(k_i\))
# - Controls the accumulation of errors in the past through an integration operation.
# - Ensures there are no steady-state errors by compensating for persistent offsets.
#
# #### Derivative Gain (\(k_d\))
# - Controls the robot's reaction to the rate of change of the error.
# - Determines the sensitivity of the controller, ensuring the correction rate is neither too aggressive nor too delayed.
#
# To test the controller, a simulator was employed, and the correseponding codes a
#  also included.

# %% [markdown]
# The following function takes as input the desired x and y positions as well as the current positions to get the errors. This will be used in the PID controller. For position, the Euclidean distance norm is used:
# \begin{equation}
# dist error = \sqrt{x_{err}^2 + y_{err}^2}
# \end{equation}
#
# For orientation, the following equation is used:
# \begin{equation}
# \phi_d = \arctan2(y_{\text{err}}, x_{\text{err}})
# \end{equation}
# \begin{equation}
# \phi_{\text{err}} = \phi_d - \phi
# \end{equation}
#
# The orientation error is then normalized to the range -180° to 180°.

# %%
## This function calculates the position and orientation errors based on the estimated and desired positions of the robot
# from https://felipenmartins.github.io/Robotics-Simulation-Labs/Lab4/
import numpy as np

async def get_pose_error(xd, yd, x, y, phi):
    """ Returns the position and orientation errors. 
        Orientation error is bounded between -pi and +pi radians.
    """
    # Position error:
    x_err = xd - x
    y_err = yd - y
    dist_err = np.sqrt(x_err**2 + y_err**2) # Euclidean distance

    # Orientation error
    phi_d = np.arctan2(y_err,x_err)
    phi_err = phi_d - phi

    # Limits the error to (-pi, pi):
    phi_err_correct = np.arctan2(np.sin(phi_err),np.cos(phi_err))

    return dist_err, phi_err_correct

# %% [markdown]
# This definition defines a PID controller defining the gains for each of the terms. It takes as input the current error, the error from the previous step, the accumulated error and the time step and applies the following equation. The Gains can be declared as a result of trial and error. The PID function is composed of the following:
# \begin{equation} P = k_p \cdot e \end{equation}
# \begin{equation} I = e_{\text{acc}} + k_i \cdot e \cdot \Delta t \end{equation}
# \begin{equation} D = k_d \cdot \frac{e - e_{\text{prev}}}{\Delta t} \end{equation}
# \begin{equation}
# \text{Output} = k_p \cdot e + k_i \cdot \int e \, dt + k_d \cdot \frac{de}{dt}
# \end{equation}

# %%
## This function implements a "goal to goal" behavior meaning that it controls the robot orientation by adjusting the angular speed
# from https://felipenmartins.github.io/Robotics-Simulation-Labs/Lab4/

async def pid_controller(e, e_prev, e_acc, delta_t, kp=1.0, kd=0, ki=0):
    """ 
    PID algortithm: must be executed every delta_t seconds
    The error e must be calculated as: e = desired_value - actual_value
    e_prev contains the error calculated in the previous step.
    e_acc contains the integration (accumulation) term.
    """
    P = kp*e                      # Proportional term; kp is the proportional gain
    I = e_acc + ki*e*delta_t      # Intergral term; ki is the integral gain
    D = kd*(e - e_prev)/delta_t   # Derivative term; kd is the derivative gain

    output = P + I + D              # controller output, angular velocity in this case

    # store values for the next iteration
    e_prev = e     # error value in the previous interation (to calculate the derivative term)
    e_acc = I      # accumulated error value (to calculate the integral term)

    return output, e_prev, e_acc

# %% [markdown]
# Taking the output of the PID controller (angular speed), the speed for each wheel is calculated with the following equations. The linear speed remains constant to avoid complex behaviors and inaccurate position estimation.
# \begin{equation} w_{r_d} = \frac{2u_d - dw_d}{2r} \end{equation}
# \begin{equation} w_{l_d} = \frac{2u_d + dw_d}{2r} \end{equation}

# %%
## This function calculates the speeds for the left and right wheels based on the desired values of linear and angular speeds
# from https://felipenmartins.github.io/Robotics-Simulation-Labs/Lab4/

async def wheel_speed_commands(u_d, w_d, d, r):
    """
    Convert desired robot speeds to desired wheel speeds
    """
    wr_d = float((2 * u_d - d * w_d) / (2 * r))
    wl_d = float((2 * u_d + d * w_d) / (2 * r))
    
    # If saturated, correct speeds to keep the original turning ratio
    #if np.abs(wl_d) > MAX_SPEED or np.abs(wr_d) > MAX_SPEED:
     #   speed_ratio = np.abs(wr_d)/np.abs(wl_d)
      #  if speed_ratio > 1:
       #     wr_d = np.sign(wr_d)*MAX_SPEED
        #    wl_d = np.sign(wl_d)*MAX_SPEED/speed_ratio
        #else:
         #   wl_d = np.sign(wl_d)*MAX_SPEED
          #  wr_d = np.sign(wr_d)*MAX_SPEED*speed_ratio
        
    return wl_d, wr_d

# %% [markdown]
# Based on the speeds of the wheels, the function updates the robot's position virtually.
#
# \begin{equation} \text{Forward Speed} = \frac{r \cdot (w_r + w_l)}{2} \end{equation}
# \begin{equation} \text{Angular Speed} = \frac{r \cdot (w_l - w_r)}{d} \end{equation}
#
# \begin{equation} x = \text{Forward Speed} \cdot \cos(\phi) \cdot \Delta t + x_{prev} \end{equation}
# \begin{equation} y = \text{Forward Speed} \cdot \sin(\phi) \cdot \Delta t + y_{prev} \end{equation}
#
# \begin{equation} \phi = \text{Angular Speed} \cdot \Delta t + phi_{prev} \end{equation}
# \begin{equation} \phi = \arctan2(\sin(\phi), \cos(\phi)) \end{equation}

# %%
async def update_odometry(x, y, phi, wl, wr, d, r, delta_t):
    # Update robot's position and orientation using odometry
    forward_speed = (wr + wl) * r / 2
    angular_speed = (wl - wr) * r / d

    x += forward_speed * np.cos(phi) * delta_t / 14
    y += forward_speed * np.sin(phi) * delta_t / 14
    phi += angular_speed * delta_t

    # Keep phi within (-pi, pi)
    phi = np.arctan2(np.sin(phi), np.cos(phi))

    return x, y, phi

# %% [markdown]
# ### 5.2 Main Control Loop combining the global and local navigationbstacles.

# %% [markdown]
# The main control loop is the bases of the robot's navigation system allowing the robot to follow the global path created with A* while continuously checking for obstacles and adjusting its movement using odometry and PID control. The loop operates as follows:
#
# 1. **Path Following**: The robot navigates in the key points (turning points in the A*) in the goal list, moving from one goal to the next.
# 2. **Obstacle Detection**: The robot checks for nearby obstacles using proximity sensors. If an obstacle is detected, it triggers an obstacle avoidance routine.
# 3. **Pose Error Calculation**: The robot calculates the error considering the next point and the current robot orientation.
# 4. **PID Controller**: A PID controller processes the orientation error to compute an angular speed command, ensuring smooth and accurate movements. Given that the Thymio actuators are not precise, this controller helps ensure the accurate path is taken. Similarly, when a local obstacle is detected, the PID controller ensures the path is retaken.
# 5. **Wheel Speed Commands**: The desired forward and angular speeds are converted into individual wheel speeds for the robot's motors.
# 6. **Odometry Updates**: The robot's position and orientation are updated in real time using odometry, based on the wheel movements.
# 7. **Goal Reached Check**: If the robot reaches a goal within a predefined tolerance, it advances to the next goal.

# %% [markdown]
# #### State Machine Archtecture
# The overall structure of the main control loop is based on a state machine.
# - **State 0: Path Following**
# The robot follows the predefined path (A*) with the PID control.
# - **State 1: Obstacle Avoidance**
# Obstacle avoidance procedure based on Neural Networks.
# - **State 2: Path Recalculation**
# Creates a new grid and recomputes the ideal path.

# %%
## Function from exercises week 8, BoMR course

def motors(left, right):
    return {
        "motor.left.target": [left],
        "motor.right.target": [right],
    }

# %%
## For testing functionality of the motor (signal reception)
node.send_set_variables(motors(100, 100))

# %%
## For testing functionality
node.send_set_variables(motors(0, 0))

# %%
import time
# Control loop

async def main_control_loop(goal_list):
    """
    Main control loop to follow global navigation path with continuous obstacle checking.
    """

    # Constant forward speed
    u_const = 4  # cm/s (adjust based on your robot's speed capabilities)

    # Robot geometric parameters
    base_width = 9.4   # cm
    wheel_radius = 2.2 # cm

    # Speed constant (convert thymio motor speed to forward speed)
    speed_constant = 0.033615 # cm/s

    # Time step
    delta_t = 0.2  # seconds

    # Initial errors for PID
    phi_err_prev = 0
    phi_err_acc = 0

    # Initial robot position and orientation
    x, y = goal_list[0][1], goal_list[0][0]
    phi = -np.pi/2  # Initial orientation, pointing north

    # Start with the first goal
    next_goal = 1
    x_goal = goal_list[next_goal][1]
    y_goal = goal_list[next_goal][0]

    control_x = [x]
    control_y = [y]
    it = 0

    while next_goal < len(goal_list):

        # determine if obstacle 
        state = await check_obstacles(proximity_threshold=2000)

        if state == 0:

            it += 1
            print("iteration", it)
            # Calculate pose error, only used orientation because the distance error is not necessary
            _, phi_err = await get_pose_error(x_goal, y_goal, x, y, phi)
            print("pose error", _, phi_err)
            # Update orientation PID
            phi_control, phi_err_prev, phi_err_acc = await pid_controller(
                phi_err, phi_err_prev, phi_err_acc, delta_t, kp=1, kd=0.05, ki=0.00)

            # Map control outputs to desired forward and angular speeds
            u_d = u_const  # Constant forward speed
            w_d = phi_control  # Angular speed from PID

            # Compute wheel speed commands
            left_speed, right_speed = await wheel_speed_commands(u_d, w_d, base_width, wheel_radius)

            # Simulate robot motion using odometry
                    # DEBUG
            print("predicted x: ", x)
            print("predicted y: ", y)
            print("goal x: ", x_goal)
            print("goal y: ", y_goal)

            

            # Scale to motor commands
            left_speed *= wheel_radius / speed_constant
            right_speed *= wheel_radius / speed_constant

            node.send_set_variables(motors(int(left_speed), int(right_speed)))

            print("left and right speeds", int(left_speed), int(right_speed))

            # Check if goal is reached
            dist_to_goal = np.sqrt((x_goal - x)**2 + (y_goal - y)**2)*14
            if dist_to_goal < 3:  # 3 cm tolerance
                print(" ")
                print('******************************* goal reached *******************************')
                next_goal += 1
                if next_goal < len(goal_list):
                    x_goal = goal_list[next_goal][1]
                    y_goal = goal_list[next_goal][0]

            print(" ")

            # Wait for the next iteration (optional for simulation)
        elif state == 1:
            print("Obstacle detected - obstacle avoidance")
            left_speed, right_speed = await obstacle_avoidance()
            print("Obstacle detected - obstacle avoidance")
        
        left_speed *=  speed_constant / wheel_radius
        right_speed *= speed_constant / wheel_radius
        
        x, y, phi = await update_odometry(x, y, phi, left_speed, right_speed, base_width, wheel_radius, delta_t)

        control_x.append(x)
        control_y.append(y)
        
        
        time.sleep(delta_t)

    left_speed = 0
    right_speed = 0
    node.send_set_variables(motors(int(left_speed), int(right_speed)))

    return control_x, control_y

# %%
control_x, control_y = await main_control_loop(goal_list)
# Out:
# Obstacle detected - obstacle avoidance
# Left Motor: 52, Right Motor: -108
# Obstacle detected - obstacle avoidance
# Obstacle detected - obstacle avoidance
# Left Motor: 52, Right Motor: -108
# Obstacle detected - obstacle avoidance
# Obstacle detected - obstacle avoidance
# Left Motor: 52, Right Motor: -108
# Obstacle detected - obstacle avoidance
# iteration 1
# pose error 1.439527732119382 -1.1068470270560662
# predicted x:  4.995414110990071
# predicted y:  8.039899437052746
# goal x:  4
# goal y:  7
# left and right speeds -74 312
#
# iteration 2
# pose error 1.4148804065852683 -0.8662609597392941
# predicted x:  5.0146483032507945
# predicted y:  7.98609096215774
# goal x:  4
# goal y:  7
# left and right speeds 6 231
#
# iteration 3
# pose error 1.3785578089747859 -0.7366255038009886
# predicted x:  5.018450655733186
# predicted y:  7.929074751848314
# goal x:  4
# goal y:  7
# left and right speeds 20 217
#
# iteration 4
# pose error 1.3367811306182962 -0.6245029576249901
# predicted x:  5.0130511507651
# predicted y:  7.872187569912938
# goal x:  4
# goal y:  7
# left and right speeds 35 202
#
# iteration 5
# pose error 1.2908562287685519 -0.531094276271401
# predicted x:  4.999719395002106
# predicted y:  7.816621659403662
# goal x:  4
# goal y:  7
# left and right speeds 48 189
#
# iteration 6
# pose error 1.241921878665136 -0.4528518087535125
# predicted x:  4.979869395692337
# predicted y:  7.7630372992801036
# goal x:  4
# goal y:  7
# left and right speeds 58 179
#
# iteration 7
# pose error 1.1908013451122879 -0.3871908985900596
# predicted x:  4.954689595918057
# predicted y:  7.71174125844091
# goal x:  4
# goal y:  7
# left and right speeds 67 170
#
# iteration 8
# pose error 1.1380931266277923 -0.33199536664426166
# predicted x:  4.925164619793512
# predicted y:  7.662817011821325
# goal x:  4
# goal y:  7
# left and right speeds 74 163
#
# iteration 9
# pose error 1.084230594821721 -0.28553460401732433
# predicted x:  4.892096125209777
# predicted y:  7.616214642907132
# goal x:  4
# goal y:  7
# left and right speeds 80 157
#
# iteration 10
# pose error 1.02952720745177 -0.24638518919748306
# predicted x:  4.856130830537969
# predicted y:  7.571809646548401
# goal x:  4
# goal y:  7
# left and right speeds 85 152
#
# iteration 11
# pose error 0.9742097394014005 -0.21337220610122554
# predicted x:  4.817788031779734
# predicted y:  7.529440602355329
# goal x:  4
# goal y:  7
# left and right speeds 90 147
#
# iteration 12
# pose error 0.9184424601465647 -0.1855236981784949
# predicted x:  4.777484015776759
# predicted y:  7.488932672064077
# goal x:  4
# goal y:  7
# left and right speeds 94 143
#
# iteration 13
# pose error 0.8623446096209038 -0.16203492704110725
# predicted x:  4.735552587039905
# predicted y:  7.4501117832729244
# goal x:  4
# goal y:  7
# left and right speeds 97 140
#
# iteration 14
# pose error 0.8060029856664136 -0.1422401491249401
# predicted x:  4.692261805385182
# predicted y:  7.412812797413091
# goal x:  4
# goal y:  7
# left and right speeds 99 138
#
# iteration 15
# pose error 0.7494809974810055 -0.12559038568578051
# predicted x:  4.647827383548597
# predicted y:  7.376883863689734
# goal x:  4
# goal y:  7
# left and right speeds 102 135
#
# iteration 16
# pose error 0.6928251790323039 -0.11163621926538747
# predicted x:  4.60242328834725
# predicted y:  7.342188413535628
# goal x:  4
# goal y:  7
# left and right speeds 103 134
#
# iteration 17
# pose error 0.6360698848538283 -0.10001513862933285
# predicted x:  4.556190065306913
# predicted y:  7.308605751196984
# goal x:  4
# goal y:  7
# left and right speeds 105 132
#
# iteration 18
# pose error 0.579240691771288 -0.09044350825299086
# predicted x:  4.509241335894722
# predicted y:  7.276030869324138
# goal x:  4
# goal y:  7
# left and right speeds 106 131
#
# iteration 19
# pose error 0.5223568885264024 -0.08271406824950445
# predicted x:  4.461668832316747
# predicted y:  7.2443739107561935
# goal x:  4
# goal y:  7
# left and right speeds 107 130
#
# iteration 20
# pose error 0.4654333397833229 -0.07670141654391216
# predicted x:  4.41354625102353
# predicted y:  7.213559574934587
# goal x:  4
# goal y:  7
# left and right speeds 108 129
#
# iteration 21
# pose error 0.40848195769749346 -0.0723812739366183
# predicted x:  4.364932124970332
# predicted y:  7.183526711758846
# goal x:  4
# goal y:  7
# left and right speeds 109 128
#
# iteration 22
# pose error 0.3515130142181568 -0.06987751112318819
# predicted x:  4.315871830109902
# predicted y:  7.154228357015677
# goal x:  4
# goal y:  7
# left and right speeds 109 128
#
# iteration 23
# pose error 0.29453663433911936 -0.0695734708776441
# predicted x:  4.26639873585041
# predicted y:  7.125632569444073
# goal x:  4
# goal y:  7
# left and right speeds 109 128
#
# iteration 24
# pose error 0.2375652350128444 -0.07239614561223505
# predicted x:  4.216534338779917
# predicted y:  7.097724720597462
# goal x:  4
# goal y:  7
# left and right speeds 108 129
#
# iteration 25
# pose error 0.1806193608132456 -0.08066187112709455
# predicted x:  4.166286865993788
# predicted y:  7.070512635027698
# goal x:  4
# goal y:  7
# left and right speeds 107 130
#
# ******************************* goal reached *******************************
#
# iteration 26
# pose error 1.116515748768174 -0.4257226042940987
# predicted x:  4.115646927044947
# predicted y:  7.04403806787908
# goal x:  3
# goal y:  7
# left and right speeds 47 190
#
# iteration 27
# pose error 1.06473498577773 -0.3454908744771501
# predicted x:  4.064575900290455
# predicted y:  7.01840495748079
# goal x:  3
# goal y:  7
# left and right speeds 73 164
#
# iteration 28
# pose error 1.0111539383447414 -0.2995439047349831
# predicted x:  4.01115220275499
# predicted y:  6.998126528939896
# goal x:  3
# goal y:  7
# left and right speeds 78 159
#
# iteration 29
# pose error 0.9567041936257842 -0.2595584447532942
# predicted x:  3.9565227016663003
# predicted y:  6.98136574932647
# goal x:  3
# goal y:  7
# left and right speeds 84 153
#
# iteration 30
# pose error 0.9015947186940998 -0.22591340335579638
# predicted x:  3.9010187568149783
# predicted y:  6.96777832026905
# goal x:  3
# goal y:  7
# left and right speeds 88 149
#
# iteration 31
# pose error 0.8460007011609462 -0.19754333681011027
# predicted x:  3.8449060348332362
# predicted y:  6.956976998393989
# goal x:  3
# goal y:  7
# left and right speeds 92 145
#
# iteration 32
# pose error 0.7900487795042284 -0.17364886999286203
# predicted x:  3.7883766812160267
# predicted y:  6.948626052215892
# goal x:  3
# goal y:  7
# left and right speeds 95 142
#
# iteration 33
# pose error 0.7338317193455176 -0.1535682623487722
# predicted x:  3.731570318748578
# predicted y:  6.942433855056094
# goal x:  3
# goal y:  7
# left and right speeds 98 139
#
# iteration 34
# pose error 0.6774177402048353 -0.13676223022360315
# predicted x:  3.6745882787685735
# predicted y:  6.938149786643221
# goal x:  3
# goal y:  7
# left and right speeds 100 137
#
# iteration 35
# pose error 0.6208573292346777 -0.1227986209515033
# predicted x:  3.617504125538964
# predicted y:  6.93556027462212
# goal x:  3
# goal y:  7
# left and right speeds 102 135
#
# iteration 36
# pose error 0.5641881938209451 -0.1113436134658361
# predicted x:  3.5603713877087046
# predicted y:  6.934484918649513
# goal x:  3
# goal y:  7
# left and right speeds 103 134
#
# iteration 37
# pose error 0.5074389071781683 -0.10216051619992861
# predicted x:  3.503229256814934
# predicted y:  6.934773014758744
# goal x:  3
# goal y:  7
# left and right speeds 105 132
#
# iteration 38
# pose error 0.4506316672055196 -0.09511998562024537
# predicted x:  3.4461068242636874
# predicted y:  6.9363006998955745
# goal x:  3
# goal y:  7
# left and right speeds 105 132
#
# iteration 39
# pose error 0.39378452563323735 -0.09023069687621144
# predicted x:  3.3890262952837613
# predicted y:  6.938968907874875
# goal x:  3
# goal y:  7
# left and right speeds 106 131
#
# iteration 40
# pose error 0.33691347596105686 -0.08771260991317929
# predicted x:  3.332005534169552
# predicted y:  6.942702394771228
# goal x:  3
# goal y:  7
# left and right speeds 106 131
#
# iteration 41
# pose error 0.28003503538714813 -0.08817229618339972
# predicted x:  3.2750602665556703
# predicted y:  6.947450301555528
# goal x:  3
# goal y:  7
# left and right speeds 106 131
#
# iteration 42
# pose error 0.2231708936472335 -0.09306401853204438
# predicted x:  3.2182063238679386
# predicted y:  6.9531892320577295
# goal x:  3
# goal y:  7
# left and right speeds 105 132
#
# iteration 43
# pose error 0.16636008700378738 -0.10613239380710215
# predicted x:  3.1614625736377544
# predicted y:  6.959931111043848
# goal x:  3
# goal y:  7
# left and right speeds 103 134
#
# ******************************* goal reached *******************************
#
# iteration 44
# pose error 2.88139317099554 0.9107389725747217
# predicted x:  3.1048560388855195
# predicted y:  6.967741766956959
# goal x:  1
# goal y:  5
# left and right speeds 281 -43
#
# iteration 45
# pose error 2.8467132520211855 0.6936052995308923
# predicted x:  3.048433935929325
# predicted y:  6.976788999707892
# goal x:  1
# goal y:  5
# left and right speeds 208 29
#
# iteration 46
# pose error 2.803011550719699 0.5787744909527133
# predicted x:  2.9914474465692673
# predicted y:  6.972564528987784
# goal x:  1
# goal y:  5
# left and right speeds 195 42
#
# iteration 47
# pose error 2.7553526408954627 0.48010549735503094
# predicted x:  2.935464856082995
# predicted y:  6.961107841643909
# goal x:  1
# goal y:  5
# left and right speeds 182 55
#
# iteration 48
# pose error 2.7047987706001586 0.39877574438780927
# predicted x:  2.881078548767647
# predicted y:  6.943573997255142
# goal x:  1
# goal y:  5
# left and right speeds 171 66
#
# iteration 49
# pose error 2.652232322358775 0.3314529731237923
# predicted x:  2.828512615062757
# predicted y:  6.921165768048395
# goal x:  1
# goal y:  5
# left and right speeds 162 75
#
# iteration 50
# pose error 2.598266263430848 0.2756853781600257
# predicted x:  2.777791608605615
# predicted y:  6.8948468465958825
# goal x:  1
# goal y:  5
# left and right speeds 155 82
#
# iteration 51
# pose error 2.543328751300515 0.22945258609271327
# predicted x:  2.7288259947533975
# predicted y:  6.865390526687847
# goal x:  1
# goal y:  5
# left and right speeds 149 88
#
# iteration 52
# pose error 2.48771749914188 0.1910981309365547
# predicted x:  2.6814687536714383
# predicted y:  6.833412442949853
# goal x:  1
# goal y:  5
# left and right speeds 144 93
#
# iteration 53
# pose error 2.431639078591 0.1592597137084688
# predicted x:  2.63554960192864
# predicted y:  6.79940159724336
# goal x:  1
# goal y:  5
# left and right speeds 140 97
#
# iteration 54
# pose error 2.3752366541745062 0.13281495597790594
# predicted x:  2.590895090915903
# predicted y:  6.763746572791506
# goal x:  1
# goal y:  5
# left and right speeds 136 101
#
# iteration 55
# pose error 2.3186093995220975 0.11083785996567519
# predicted x:  2.5473397798889503
# predicted y:  6.726756830919003
# goal x:  1
# goal y:  5
# left and right speeds 133 104
#
# iteration 56
# pose error 2.2618260155427747 0.09256362832678944
# predicted x:  2.504731892389958
# predicted y:  6.688679619291546
# goal x:  1
# goal y:  5
# left and right speeds 131 106
#
# iteration 57
# pose error 2.2049341105263496 0.07736006235993599
# predicted x:  2.462935639820295
# predicted y:  6.649713231293915
# goal x:  1
# goal y:  5
# left and right speeds 129 108
#
# iteration 58
# pose error 2.147966695875444 0.06470420522602627
# predicted x:  2.4218315943735798
# predicted y:  6.6100173427113
# goal x:  1
# goal y:  5
# left and right speeds 127 110
#
# iteration 59
# pose error 2.09094667957545 0.05416320625159177
# predicted x:  2.3813159753504762
# predicted y:  6.569721055815065
# goal x:  1
# goal y:  5
# left and right speeds 126 111
#
# iteration 60
# pose error 2.0338899732121054 0.04537860601490662
# predicted x:  2.341299381223508
# predicted y:  6.528929165482225
# goal x:  1
# goal y:  5
# left and right speeds 125 112
#
# iteration 61
# pose error 1.9768076403201529 0.03805340785776812
# predicted x:  2.3017052891722236
# predicted y:  6.487727053921246
# goal x:  1
# goal y:  5
# left and right speeds 124 113
#
# iteration 62
# pose error 1.9197073823195268 0.031941427614393
# predicted x:  2.2624685110031573
# predicted y:  6.446184529186217
# goal x:  1
# goal y:  5
# left and right speeds 123 114
#
# iteration 63
# pose error 1.8625945668336166 0.026838511156566547
# predicted x:  2.2235337113686806
# predicted y:  6.404358849276954
# goal x:  1
# goal y:  5
# left and right speeds 122 115
#
# iteration 64
# pose error 1.8054729398195302 0.02257528638446038
# predicted x:  2.184854042937923
# predicted y:  6.36229711640091
# goal x:  1
# goal y:  5
# left and right speeds 122 115
#
# iteration 65
# pose error 1.7483451191411787 0.019011177694772563
# predicted x:  2.1463899220603166
# predicted y:  6.320038182108125
# goal x:  1
# goal y:  5
# left and right speeds 121 116
#
# iteration 66
# pose error 1.6912129369805695 0.01602946034943864
# predicted x:  2.1081079500779203
# predicted y:  6.277614170704346
# goal x:  1
# goal y:  5
# left and right speeds 121 116
#
# iteration 67
# pose error 1.634077677623836 0.013533172167735419
# predicted x:  2.069979975043132
# predicted y:  6.235051703174895
# goal x:  1
# goal y:  5
# left and right speeds 120 117
#
# iteration 68
# pose error 1.5769402427710744 0.011441732519654304
# predicted x:  2.0319822831554517
# predicted y:  6.192372884849432
# goal x:  1
# goal y:  5
# left and right speeds 120 117
#
# iteration 69
# pose error 1.5198012665937704 0.009688145191675268
# predicted x:  1.9940949068154634
# predicted y:  6.149596105675199
# goal x:  1
# goal y:  5
# left and right speeds 120 117
#
# iteration 70
# pose error 1.4626611959141158 0.008216683477974662
# predicted x:  1.956301035581674
# predicted y:  6.106736691078022
# goal x:  1
# goal y:  5
# left and right speeds 120 117
#
# iteration 71
# pose error 1.405520346151016 0.006980973727168216
# predicted x:  1.9185865167338583
# predicted y:  6.063807433100196
# goal x:  1
# goal y:  5
# left and right speeds 119 118
#
# iteration 72
# pose error 1.3483789404097963 0.005942408269692834
# predicted x:  1.8809394331125937
# predicted y:  6.020819025159654
# goal x:  1
# goal y:  5
# left and right speeds 119 118
#
# iteration 73
# pose error 1.2912371368330202 0.00506883074534592
# predicted x:  1.843349747121941
# predicted y:  5.977780418890711
# goal x:  1
# goal y:  5
# left and right speeds 119 118
#
# iteration 74
# pose error 1.2340950477660642 0.00433344681566572
# predicted x:  1.805809001072532
# predicted y:  5.934699117743893
# goal x:  1
# goal y:  5
# left and right speeds 119 118
#
# iteration 75
# pose error 1.1769527532078872 0.0037139214660215636
# predicted x:  1.768310065302729
# predicted y:  5.891581419074075
# goal x:  1
# goal y:  5
# left and right speeds 119 118
#
# iteration 76
# pose error 1.1198103102664048 0.0031916308926946972
# predicted x:  1.7308469266905069
# predicted y:  5.8484326141338405
# goal x:  1
# goal y:  5
# left and right speeds 119 118
#
# iteration 77
# pose error 1.0626677598165923 0.002751042591447206
# predicted x:  1.6934145112320842
# predicted y:  5.805257153564241
# goal x:  1
# goal y:  5
# left and right speeds 119 118
#
# iteration 78
# pose error 1.0055251311972708 0.0023792019339432535
# predicted x:  1.656008535306852
# predicted y:  5.7620587845263955
# goal x:  1
# goal y:  5
# left and right speeds 119 118
#
# iteration 79
# pose error 0.9483824455306024 0.002065307423269047
# predicted x:  1.61862538107401
# predicted y:  5.718840664460242
# goal x:  1
# goal y:  5
# left and right speeds 119 118
#
# iteration 80
# pose error 0.8912397180728864 0.0018003601255971446
# predicted x:  1.5812619921627002
# predicted y:  5.675605455526883
# goal x:  1
# goal y:  5
# left and right speeds 119 118
#
# iteration 81
# pose error 0.8340969598829528 0.0015768756417382512
# predicted x:  1.5439157864356379
# predicted y:  5.632355403038581
# goal x:  1
# goal y:  5
# left and right speeds 119 118
#
# iteration 82
# pose error 0.7769541790090706 0.0013886495850354843
# predicted x:  1.5065845831391722
# predicted y:  5.589092400566643
# goal x:  1
# goal y:  5
# left and right speeds 119 118
#
# iteration 83
# pose error 0.7198113813356658 0.0012305700995778324
# predicted x:  1.4692665422142528
# predicted y:  5.545818043910824
# goal x:  1
# goal y:  5
# left and right speeds 119 118
#
# iteration 84
# pose error 0.6626685711894658 0.0010984738442161301
# predicted x:  1.4319601139479552
# predicted y:  5.502533675687866
# goal x:  1
# goal y:  5
# left and right speeds 119 118
#
# iteration 85
# pose error 0.6055257517755936 0.0009890457411017017
# predicted x:  1.3946639975113484
# predicted y:  5.459240421927078
# goal x:  1
# goal y:  5
# left and right speeds 119 118
#
# iteration 86
# pose error 0.5483829254939768 0.0008997689938290421
# predicted x:  1.3573771072789726
# predicted y:  5.415939221721451
# goal x:  1
# goal y:  5
# left and right speeds 119 118
#
# iteration 87
# pose error 0.49124009417277603 0.000828943461983922
# predicted x:  1.320098546191357
# predicted y:  5.372630850640493
# goal x:  1
# goal y:  5
# left and right speeds 119 118
#
# iteration 88
# pose error 0.4340972592470776 0.0007758148933674214
# predicted x:  1.2828275858621006
# predicted y:  5.329315938213201
# goal x:  1
# goal y:  5
# left and right speeds 119 118
#
# iteration 89
# pose error 0.37695442190792205 0.0007409148034804858
# predicted x:  1.245563653755985
# predicted y:  5.285994979239053
# goal x:  1
# goal y:  5
# left and right speeds 119 118
#
# iteration 90
# pose error 0.31981158325192444 0.0007268609985646712
# predicted x:  1.2083063288131972
# predicted y:  5.242668337774978
# goal x:  1
# goal y:  5
# left and right speeds 119 118
#
# iteration 91
# pose error 0.2626687444880077 0.000740318070926449
# predicted x:  1.1710553489346862
# predicted y:  5.199336240888954
# goal x:  1
# goal y:  5
# left and right speeds 119 118
#
# iteration 92
# pose error 0.20552590735807183 0.0007974139808788472
# predicted x:  1.1338106382791717
# predicted y:  5.155998755375418
# goal x:  1
# goal y:  5
# left and right speeds 119 118
#
# ******************************* goal reached *******************************
#
# iteration 93
# pose error 2.1148618063214624 0.6639416716648756
# predicted x:  1.096572373900126
# predicted y:  5.112655730694562
# goal x:  1
# goal y:  3
# left and right speeds 235 2
#
# iteration 94
# pose error 2.0701573444086856 0.515006720759914
# predicted x:  1.0593411462139712
# predicted y:  5.0693066614146955
# goal x:  1
# goal y:  3
# left and right speeds 185 52
#
# iteration 95
# pose error 2.0206225470170436 0.43338154059466066
# predicted x:  1.0297819929546523
# predicted y:  5.020403056424459
# goal x:  1
# goal y:  3
# left and right speeds 176 61
#
# iteration 96
# pose error 1.9689087352026082 0.36297460672871895
# predicted x:  1.005023540913825
# predicted y:  4.968902326575349
# goal x:  1
# goal y:  3
# left and right speeds 167 70
#
# iteration 97
# pose error 1.9155964796491172 0.30449168219116074
# predicted x:  0.9845983617765357
# predicted y:  4.91553456308784
# goal x:  1
# goal y:  3
# left and right speeds 159 78
#
# iteration 98
# pose error 1.8611610748608969 0.2557225757495529
# predicted x:  0.9679053153773948
# predicted y:  4.860884326817856
# goal x:  1
# goal y:  3
# left and right speeds 153 84
#
# iteration 99
# pose error 1.8059343018869194 0.21502020063324578
# predicted x:  0.9544068425521179
# predicted y:  4.805358680906852
# goal x:  1
# goal y:  3
# left and right speeds 147 90
#
# iteration 100
# pose error 1.7501497953369987 0.18101783036279295
# predicted x:  0.9436277439209437
# predicted y:  4.7492416856634465
# goal x:  1
# goal y:  3
# left and right speeds 143 94
#
# iteration 101
# pose error 1.693971835715237 0.1525874125352431
# predicted x:  0.9351560998050228
# predicted y:  4.692730294170915
# goal x:  1
# goal y:  3
# left and right speeds 139 98
#
# iteration 102
# pose error 1.6375159494494897 0.12879553712490033
# predicted x:  0.9286389488632179
# predicted y:  4.635960294469923
# goal x:  1
# goal y:  3
# left and right speeds 136 101
#
# iteration 103
# pose error 1.580863425953581 0.10886870195641407
# predicted x:  0.9237761010384106
# predicted y:  4.5790247270846605
# goal x:  1
# goal y:  3
# left and right speeds 133 104
#
# iteration 104
# pose error 1.5240715210845595 0.09216513054131381
# predicted x:  0.9203134593586375
# predicted y:  4.521986877940022
# goal x:  1
# goal y:  3
# left and right speeds 131 106
#
# iteration 105
# pose error 1.467180615387401 0.07815180230570928
# predicted x:  0.9180365779265033
# predicted y:  4.464889400470409
# goal x:  1
# goal y:  3
# left and right speeds 129 108
#
# iteration 106
# pose error 1.4102192319833846 0.06638564483354492
# predicted x:  0.9167647898850955
# predicted y:  4.407760697722782
# goal x:  1
# goal y:  3
# left and right speeds 127 110
#
# iteration 107
# pose error 1.353207553769195 0.05649808260545486
# predicted x:  0.9163460259477959
# predicted y:  4.350619375028836
# goal x:  1
# goal y:  3
# left and right speeds 126 111
#
# iteration 108
# pose error 1.2961598897616695 0.048182311688200974
# predicted x:  0.9166523322862615
# predicted y:  4.293477338848139
# goal x:  1
# goal y:  3
# left and right speeds 125 112
#
# iteration 109
# pose error 1.2390864059171702 0.04118280021654219
# predicted x:  0.9175760420534492
# predicted y:  4.236341948040733
# goal x:  1
# goal y:  3
# left and right speeds 124 113
#
# iteration 110
# pose error 1.1819943410704394 0.03528661382933573
# predicted x:  0.9190265318890561
# predicted y:  4.179217503170907
# goal x:  1
# goal y:  3
# left and right speeds 123 114
#
# iteration 111
# pose error 1.1248888622544226 0.030316242396805748
# predicted x:  0.9209274887055013
# predicted y:  4.12210627410314
# goal x:  1
# goal y:  3
# left and right speeds 123 114
#
# iteration 112
# pose error 1.0677736672321798 0.026123665359610415
# predicted x:  0.9232146145660415
# predicted y:  4.065009206072049
# goal x:  1
# goal y:  3
# left and right speeds 122 115
#
# iteration 113
# pose error 1.010651409639026 0.022585441913171245
# predicted x:  0.9258337039198132
# predicted y:  4.007926402239319
# goal x:  1
# goal y:  3
# left and right speeds 122 115
#
# iteration 114
# pose error 0.9535239994893507 0.019598652090590418
# predicted x:  0.9287390353473027
# predicted y:  3.95085745120861
# goal x:  1
# goal y:  3
# left and right speeds 121 116
#
# iteration 115
# pose error 0.8963928159933271 0.017077547809170257
# predicted x:  0.9318920279938245
# predicted y:  3.8938016472985786
# goal x:  1
# goal y:  3
# left and right speeds 121 116
#
# iteration 116
# pose error 0.8392588585871325 0.014950801071409892
# predicted x:  0.9352601204048442
# predicted y:  3.8367581369230783
# goal x:  1
# goal y:  3
# left and right speeds 121 116
#
# iteration 117
# pose error 0.7821228543641189 0.013159261621925378
# predicted x:  0.9388158362784611
# predicted y:  3.779726014333479
# goal x:  1
# goal y:  3
# left and right speeds 120 117
#
# iteration 118
# pose error 0.7249853346991005 0.011654160684039683
# predicted x:  0.9425360076785516
# predicted y:  3.722704382936237
# goal x:  1
# goal y:  3
# left and right speeds 120 117
#
# iteration 119
# pose error 0.6678466900847903 0.010395724232177049
# predicted x:  0.9464011315884816
# predicted y:  3.66569239349884
# goal x:  1
# goal y:  3
# left and right speeds 120 117
#
# iteration 120
# pose error 0.6107072095641748 0.009352194455344298
# predicted x:  0.9503948404944443
# predicted y:  3.6086892671668274
# goal x:  1
# goal y:  3
# left and right speeds 120 117
#
# iteration 121
# pose error 0.5535671093129617 0.008499313477585035
# predicted x:  0.9545034722207593
# predicted y:  3.5516943089004465
# goal x:  1
# goal y:  3
# left and right speeds 120 117
#
# iteration 122
# pose error 0.49642655368249566 0.007820425426615875
# predicted x:  0.9587157288879771
# predicted y:  3.494706915415409
# goal x:  1
# goal y:  3
# left and right speeds 120 117
#
# iteration 123
# pose error 0.43928567123198387 0.007307565762010526
# predicted x:  0.9630224202988589
# predicted y:  3.43772658081179
# goal x:  1
# goal y:  3
# left and right speeds 119 117
#
# iteration 124
# pose error 0.3821445679527933 0.006964401307038459
# predicted x:  0.9674162945621202
# predicted y:  3.38075290275422
# goal x:  1
# goal y:  3
# left and right speeds 119 118
#
# iteration 125
# pose error 0.3250033402512812 0.006813167210691472
# predicted x:  0.9718919710725465
# predicted y:  3.323785592459429
# goal x:  1
# goal y:  3
# left and right speeds 119 118
#
# iteration 126
# pose error 0.2678620922944155 0.0069115335553899815
# predicted x:  0.9764460145071506
# predicted y:  3.2668244933579835
# goal x:  1
# goal y:  3
# left and right speeds 119 118
#
# iteration 127
# pose error 0.21072097009114352 0.0073985494309700695
# predicted x:  0.981077240112541
# predicted y:  3.209869617606728
# goal x:  1
# goal y:  3
# left and right speeds 120 117
#
# ******************************* goal reached *******************************
#
# iteration 128
# pose error 1.5355306566052926 0.6374530323892296
# predicted x:  0.9857874704655682
# predicted y:  3.1529212212072646
# goal x:  2
# goal y:  2
# left and right speeds 230 7
#
# iteration 129
# pose error 1.489998012562035 0.5012862818530959
# predicted x:  0.990583349302376
# predicted y:  3.095979973691675
# goal x:  2
# goal y:  2
# left and right speeds 184 53
#
# iteration 130
# pose error 1.4401475424858599 0.42690616654218144
# predicted x:  1.0043339224899415
# predicted y:  3.0405162210286756
# goal x:  2
# goal y:  2
# left and right speeds 176 61
#
# iteration 131
# pose error 1.3883348203492523 0.36228703522193345
# predicted x:  1.0231999869154929
# predicted y:  2.986577573144807
# goal x:  2
# goal y:  2
# left and right speeds 167 70
#
# iteration 132
# pose error 1.3350547971693123 0.308230741439543
# predicted x:  1.0464030361421581
# predicted y:  2.9343576092513506
# goal x:  2
# goal y:  2
# left and right speeds 160 77
#
# iteration 133
# pose error 1.2807223108018557 0.2628236308951285
# predicted x:  1.0731626256380475
# predicted y:  2.8838677043944343
# goal x:  2
# goal y:  2
# left and right speeds 154 83
#
# iteration 134
# pose error 1.2256316463434591 0.22464264598556172
# predicted x:  1.1028500632671177
# predicted y:  2.835041869332768
# goal x:  2
# goal y:  2
# left and right speeds 149 88
#
# iteration 135
# pose error 1.169993818835918 0.19250294981267846
# predicted x:  1.13495459077139
# predicted y:  2.7877702559038147
# goal x:  2
# goal y:  2
# left and right speeds 144 93
#
# iteration 136
# pose error 1.1139601246465227 0.16542345739620865
# predicted x:  1.1690623883517148
# predicted y:  2.741923072057164
# goal x:  2
# goal y:  2
# left and right speeds 141 96
#
# iteration 137
# pose error 1.0576392005454538 0.14258976298440318
# predicted x:  1.2048380600576136
# predicted y:  2.6973651610150076
# goal x:  2
# goal y:  2
# left and right speeds 138 99
#
# iteration 138
# pose error 1.0011092040423728 0.12332499077171777
# predicted x:  1.2420093403318788
# predicted y:  2.6539646766257636
# goal x:  2
# goal y:  2
# left and right speeds 135 102
#
# iteration 139
# pose error 0.9444265004085994 0.10706622167160507
# predicted x:  1.2803546871625924
# predicted y:  2.611597938506323
# goal x:  2
# goal y:  2
# left and right speeds 133 104
#
# iteration 140
# pose error 0.8876318542626868 0.09334538490219213
# predicted x:  1.3196933360227021
# predicted y:  2.5701518671809254
# goal x:  2
# goal y:  2
# left and right speeds 131 106
#
# iteration 141
# pose error 0.8307548441287665 0.0817737666627133
# predicted x:  1.3598773794153398
# predicted y:  2.529524920715955
# goal x:  2
# goal y:  2
# left and right speeds 130 107
#
# iteration 142
# pose error 0.7738170135270203 0.07202952278504116
# predicted x:  1.4007854818619507
# predicted y:  2.4896271353555295
# goal x:  2
# goal y:  2
# left and right speeds 128 109
#
# iteration 143
# pose error 0.7168341244585716 0.0638477742342104
# predicted x:  1.4423179018857293
# predicted y:  2.450379661431499
# goal x:  2
# goal y:  2
# left and right speeds 127 110
#
# iteration 144
# pose error 0.6598177736399196 0.05701305136138424
# predicted x:  1.4843925548141386
# predicted y:  2.4117140474650447
# goal x:  2
# goal y:  2
# left and right speeds 126 111
#
# iteration 145
# pose error 0.6027765570823845 0.05135407911343903
# predicted x:  1.5269419065685528
# predicted y:  2.3735714362837412
# goal x:  2
# goal y:  2
# left and right speeds 125 112
#
# iteration 146
# pose error 0.5457169162489917 0.046741239090517306
# predicted x:  1.5699105375618938
# predicted y:  2.33590178174581
# goal x:  2
# goal y:  2
# left and right speeds 125 112
#
# iteration 147
# pose error 0.4886437633725653 0.0430876727053593
# predicted x:  1.613253258603595
# predicted y:  2.2986631639525803
# goal x:  2
# goal y:  2
# left and right speeds 124 113
#
# iteration 148
# pose error 0.43156096151926954 0.040356308018765996
# predicted x:  1.6569337004356677
# predicted y:  2.2618212703556995
# goal x:  2
# goal y:  2
# left and right speeds 124 113
#
# iteration 149
# pose error 0.3744717272499051 0.03857818998885598
# predicted x:  1.7009233408056936
# predicted y:  2.2253491212201637
# goal x:  2
# goal y:  2
# left and right speeds 124 113
#
# iteration 150
# pose error 0.3173790392759766 0.037895643457722006
# predicted x:  1.745200988686441
# predicted y:  2.1892271608553453
# goal x:  2
# goal y:  2
# left and right speeds 124 113
#
# iteration 151
# pose error 0.2602862117723651 0.038668301446898146
# predicted x:  1.7897528386672565
# predicted y:  2.1534439415237103
# goal x:  2
# goal y:  2
# left and right speeds 124 113
#
# iteration 152
# pose error 0.20319807866071227 0.04176771604113372
# predicted x:  1.8345734024286289
# predicted y:  2.1179978812833715
# goal x:  2
# goal y:  2
# left and right speeds 124 113
#
# ******************************* goal reached *******************************
#
# iteration 153
# pose error 2.086374215734847 -0.8602371467429273
# predicted x:  1.8796681068232302
# predicted y:  2.0829012467151897
# goal x:  2
# goal y:  0
# left and right speeds -32 270
#
# iteration 154
# pose error 2.0495600835181826 -0.6642244263761038
# predicted x:  1.9250597955177327
# predicted y:  2.0481895668378
# goal x:  2
# goal y:  0
# left and right speeds 32 205
#
# iteration 155
# pose error 2.0048755573403314 -0.5587510676469374
# predicted x:  1.9619070396928449
# predicted y:  2.0045136384658853
# goal x:  2
# goal y:  0
# left and right speeds 44 193
#
# iteration 156
# pose error 1.9566576203520705 -0.46775715775841054
# predicted x:  1.993115182439798
# predicted y:  1.9566455076403058
# goal x:  2
# goal y:  0
# left and right speeds 56 181
#
# iteration 157
# pose error 1.9058271119801338 -0.3922748382760695
# predicted x:  2.0190593769387544
# predicted y:  1.9057318071830684
# goal x:  2
# goal y:  0
# left and right speeds 66 171
#
# iteration 158
# pose error 1.8531534851121658 -0.32938239578514406
# predicted x:  2.040375455607035
# predicted y:  1.852713594155311
# goal x:  2
# goal y:  0
# left and right speeds 75 162
#
# iteration 159
# pose error 1.7991774412403791 -0.2769239438365716
# predicted x:  2.057676353690811
# predicted y:  1.7982527362117957
# goal x:  2
# goal y:  0
# left and right speeds 82 155
#
# iteration 160
# pose error 1.7442816355756843 -0.23311874859304837
# predicted x:  2.071529030523555
# predicted y:  1.7428143968876733
# goal x:  2
# goal y:  0
# left and right speeds 87 150
#
# iteration 161
# pose error 1.6887360507003564 -0.19650227600941395
# predicted x:  2.0824387568820844
# predicted y:  1.6867226506746074
# goal x:  2
# goal y:  0
# left and right speeds 92 145
#
# iteration 162
# pose error 1.6327309982124205 -0.1658657756298605
# predicted x:  2.090846183284998
# predicted y:  1.6302016695814896
# goal x:  2
# goal y:  0
# left and right speeds 96 141
#
# iteration 163
# pose error 1.576400615302497 -0.14020940972831752
# predicted x:  2.097130383665392
# predicted y:  1.5734054113594198
# goal x:  2
# goal y:  0
# left and right speeds 100 137
#
# iteration 164
# pose error 1.5198394951543723 -0.11870470224731289
# predicted x:  2.101614629219439
# predicted y:  1.5164387749459893
# goal x:  2
# goal y:  0
# left and right speeds 103 134
#
# iteration 165
# pose error 1.463114409910956 -0.10066422073096226
# predicted x:  2.104573077467319
# predicted y:  1.4593725528315582
# goal x:  2
# goal y:  0
# left and right speeds 105 132
#
# iteration 166
# pose error 1.406272555701701 -0.08551692429315572
# predicted x:  2.1062374304045903
# predicted y:  1.402253938950012
# goal x:  2
# goal y:  0
# left and right speeds 107 130
#
# iteration 167
# pose error 1.3493473453067961 -0.07278801445254614
# predicted x:  2.106803105509529
# predicted y:  1.3451138817735913
# goal x:  2
# goal y:  0
# left and right speeds 109 128
#
# iteration 168
# pose error 1.2923624768232211 -0.06208240267625453
# predicted x:  2.106434734117555
# predicted y:  1.2879722119960415
# goal x:  2
# goal y:  0
# left and right speeds 110 127
#
# iteration 169
# pose error 1.2353347923429876 -0.05307110677715854
# predicted x:  2.105270945934467
# predicted y:  1.230841207108031
# goal x:  2
# goal y:  0
# left and right speeds 111 126
#
# iteration 170
# pose error 1.1782762879781388 -0.045480034132034275
# predicted x:  2.1034284709698254
# predicted y:  1.1737280614368841
# goal x:  2
# goal y:  0
# left and right speeds 112 125
#
# iteration 171
# pose error 1.1211955286713977 -0.03908071966740034
# predicted x:  2.101005622764271
# predicted y:  1.1166365915922407
# goal x:  2
# goal y:  0
# left and right speeds 113 124
#
# iteration 172
# pose error 1.0640986453530679 -0.033682671376061624
# predicted x:  2.098085237774689
# predicted y:  1.0595684089160629
# goal x:  2
# goal y:  0
# left and right speeds 114 123
#
# iteration 173
# pose error 1.006990038799928 -0.029127042858039912
# predicted x:  2.0947371455758526
# predicted y:  1.002523721160961
# goal x:  2
# goal y:  0
# left and right speeds 115 122
#
# iteration 174
# pose error 0.9498728773067555 -0.025281405907950028
# predicted x:  2.091020238956561
# predicted y:  0.9455018768586899
# goal x:  2
# goal y:  0
# left and right speeds 115 122
#
# iteration 175
# pose error 0.8927494492283495 -0.022035440067159184
# predicted x:  2.0869842052121372
# predicted y:  0.8885017316477972
# goal x:  2
# goal y:  0
# left and right speeds 116 121
#
# iteration 176
# pose error 0.8356214132292883 -0.019297393186943124
# predicted x:  2.0826709716357144
# predicted y:  0.831521891892282
# goal x:  2
# goal y:  0
# left and right speeds 116 121
#
# iteration 177
# pose error 0.7784899763332669 -0.01699120007910615
# predicted x:  2.078115910205888
# predicted y:  0.7745608741887728
# goal x:  2
# goal y:  0
# left and right speeds 116 121
#
# iteration 178
# pose error 0.7213560209458513 -0.015054178349862335
# predicted x:  2.0733488390926564
# predicted y:  0.7176172076801051
# goal x:  2
# goal y:  0
# left and right speeds 116 121
#
# iteration 179
# pose error 0.6642201957850068 -0.013435256031432807
# predicted x:  2.0683948519124535
# predicted y:  0.6606894979644722
# goal x:  2
# goal y:  0
# left and right speeds 117 120
#
# iteration 180
# pose error 0.6070829812952753 -0.012093732634070431
# predicted x:  2.0632749995314263
# predicted y:  0.6037764657658143
# goal x:  2
# goal y:  0
# left and right speeds 117 120
#
# iteration 181
# pose error 0.5499447370967954 -0.010998649940936023
# predicted x:  2.0580068433618277
# predicted y:  0.5468769696957989
# goal x:  2
# goal y:  0
# left and right speeds 117 120
#
# iteration 182
# pose error 0.4928057369689745 -0.01012898753063096
# predicted x:  2.052604893024707
# predicted y:  0.4899900199181543
# goal x:  2
# goal y:  0
# left and right speeds 117 120
#
# iteration 183
# pose error 0.4356661955920103 -0.00947518925783375
# predicted x:  2.0470809340744704
# predicted y:  0.433114788050802
# goal x:  2
# goal y:  0
# left and right speeds 117 120
#
# iteration 184
# pose error 0.3785262907730441 -0.009043208198913799
# predicted x:  2.041444241461147
# predicted y:  0.3762506181471458
# goal x:  2
# goal y:  0
# left and right speeds 117 120
#
# iteration 185
# pose error 0.3213861856069237 -0.008864037875150999
# predicted x:  2.035701657814458
# predicted y:  0.3193970443323911
# goal x:  2
# goal y:  0
# left and right speeds 117 120
#
# iteration 186
# pose error 0.2642460587821692 -0.009017001235781974
# predicted x:  2.0298574836337537
# predicted y:  0.26255382353523204
# goal x:  2
# goal y:  0
# left and right speeds 117 120
#
# iteration 187
# pose error 0.20710616559611264 -0.00969381097421218
# predicted x:  2.023913055734622
# predicted y:  0.20572099939811028
# goal x:  2
# goal y:  0
# left and right speeds 117 120
#
# ******************************* goal reached *******************************
#
# iteration 188
# pose error 2.0233519092216814 -1.3891397774155176
# predicted x:  2.0178657106442226
# predicted y:  0.14889903410469052
# goal x:  0
# goal y:  0
# left and right speeds -123 361
#
# iteration 189
# pose error 2.0138129511040157 -1.070251705808099
# predicted x:  2.0117062902309875
# predicted y:  0.09208910836435882
# goal x:  0
# goal y:  0
# left and right speeds -19 257
#
# iteration 190
# pose error 1.9870224236052472 -0.8973784816854367
# predicted x:  1.986604427498102
# predicted y:  0.04075488381787951
# goal x:  0
# goal y:  0
# left and right speeds 0 238
#
# iteration 191
# pose error 1.9518958066109198 -0.7494329990801856
# predicted x:  1.9518903035866462
# predicted y:  -0.004634935784197186
# goal x:  0
# goal y:  0
# left and right speeds 19 218
#
# iteration 192
# pose error 1.9104595612957271 -0.6273208476260275
# predicted x:  1.9099651151000774
# predicted y:  -0.043462563741808305
# goal x:  0
# goal y:  0
# left and right speeds 35 202
#
# iteration 193
# pose error 1.8644982562730643 -0.5259528624232728
# predicted x:  1.862950994714203
# predicted y:  -0.07594299795675516
# goal x:  0
# goal y:  0
# left and right speeds 48 188
#
# iteration 194
# pose error 1.8153051827708602 -0.44163466579472327
# predicted x:  1.8124037501569292
# predicted y:  -0.10259411782283495
# goal x:  0
# goal y:  0
# left and right speeds 60 177
#
# iteration 195
# pose error 1.7638140527791843 -0.37137128041875683
# predicted x:  1.7594457360573403
# predicted y:  -0.1240593190815404
# goal x:  0
# goal y:  0
# left and right speeds 69 168
#
# iteration 196
# pose error 1.7106922791039623 -0.3127323524367507
# predicted x:  1.7048716096673173
# predicted y:  -0.14099953310659877
# goal x:  0
# goal y:  0
# left and right speeds 77 160
#
# iteration 197
# pose error 1.656414350443673 -0.2637316454554226
# predicted x:  1.6492363483299541
# predicted y:  -0.15403885127789418
# goal x:  0
# goal y:  0
# left and right speeds 83 154
#
# iteration 198
# pose error 1.601316557412078 -0.22273800911924393
# predicted x:  1.5929230461553707
# predicted y:  -0.16374030068728807
# goal x:  0
# goal y:  0
# left and right speeds 89 148
#
# iteration 199
# pose error 1.545636886772938 -0.18840697766622339
# predicted x:  1.536193216082684
# predicted y:  -0.17059832535719702
# goal x:  0
# goal y:  0
# left and right speeds 93 144
#
# iteration 200
# pose error 1.489543688380122 -0.15962730301460162
# predicted x:  1.4792232433519674
# predicted y:  -0.17503998377611912
# goal x:  0
# goal y:  0
# left and right speeds 97 140
#
# iteration 201
# pose error 1.433156094097994 -0.13547853965710768
# predicted x:  1.4221304020083911
# predicted y:  -0.17743029542237093
# goal x:  0
# goal y:  0
# left and right speeds 100 137
#
# iteration 202
# pose error 1.3765584841561493 -0.11519701372432765
# predicted x:  1.3649912294817008
# predicted y:  -0.17807920636702762
# goal x:  0
# goal y:  0
# left and right speeds 103 134
#
# iteration 203
# pose error 1.3198107043359284 -0.09814828289801181
# predicted x:  1.3078544059889345
# predicted y:  -0.17724883078607456
# goal x:  0
# goal y:  0
# left and right speeds 105 132
#
# iteration 204
# pose error 1.2629552703827718 -0.08380470483983649
# predicted x:  1.2507497287156686
# predicted y:  -0.1751603011681065
# goal x:  0
# goal y:  0
# left and right speeds 107 130
#
# iteration 205
# pose error 1.2060224449946937 -0.07172707896472197
# predicted x:  1.1936943327198615
# predicted y:  -0.17199993564959146
# goal x:  0
# goal y:  0
# left and right speeds 109 128
#
# iteration 206
# pose error 1.1490338160445641 -0.06154956953652935
# predicted x:  1.1366969816388757
# predicted y:  -0.16792463293693077
# goal x:  0
# goal y:  0
# left and right speeds 110 127
#
# iteration 207
# pose error 1.0920048201086672 -0.05296729351408347
# predicted x:  1.0797610110219658
# predicted y:  -0.16306650857053584
# goal x:  0
# goal y:  0
# left and right speeds 111 126
#
# iteration 208
# pose error 1.0349465240163342 -0.04572608683290014
# predicted x:  1.022886334520708
# predicted y:  -0.15753683450000835
# goal x:  0
# goal y:  0
# left and right speeds 112 125
#
# iteration 209
# pose error 0.9778668842641682 -0.03961406218350661
# predicted x:  0.9660708005133332
# predicted y:  -0.1514293621991449
# goal x:  0
# goal y:  0
# left and right speeds 113 124
#
# iteration 210
# pose error 0.9207716387406207 -0.03445464928155628
# predicted x:  0.9093111001749042
# predicted y:  -0.1448231121326754
# goal x:  0
# goal y:  0
# left and right speeds 114 123
#
# iteration 211
# pose error 0.8636649392642143 -0.03010087172720155
# predicted x:  0.852603367196931
# predicted y:  -0.13778470727448025
# goal x:  0
# goal y:  0
# left and right speeds 114 123
#
# iteration 212
# pose error 0.8065498012053207 -0.026430667961060642
# predicted x:  0.7959435667852948
# predicted y:  -0.1303703199253777
# goal x:  0
# goal y:  0
# left and right speeds 115 122
#
# iteration 213
# pose error 0.7494284238609317 -0.023343112329447635
# predicted x:  0.7393277418392212
# predicted y:  -0.12262729156920193
# goal x:  0
# goal y:  0
# left and right speeds 115 122
#
# iteration 214
# pose error 0.6923024194127319 -0.020755441616667095
# predicted x:  0.6827521635242868
# predicted y:  -0.11459547603473533
# goal x:  0
# goal y:  0
# left and right speeds 116 121
#
# iteration 215
# pose error 0.6351729772101637 -0.01860085148020607
# predicted x:  0.6262134191258361
# predicted y:  -0.10630834720168139
# goal x:  0
# goal y:  0
# left and right speeds 116 121
#
# iteration 216
# pose error 0.5780409823861684 -0.016827112683473366
# predicted x:  0.569708460254549
# predicted y:  -0.09779390386091392
# goal x:  0
# goal y:  0
# left and right speeds 116 121
#
# iteration 217
# pose error 0.5209071024868647 -0.015396204223253385
# predicted x:  0.5132346279255705
# predicted y:  -0.08907539570140635
# goal x:  0
# goal y:  0
# left and right speeds 116 121
#
# iteration 218
# pose error 0.4637718522869261 -0.01428545201713316
# predicted x:  0.4567896669708964
# predicted y:  -0.08017188486161425
# goal x:  0
# goal y:  0
# left and right speeds 117 120
#
# iteration 219
# pose error 0.40663564504286004 -0.013491308898054388
# predicted x:  0.40037174033154327
# predicted y:  -0.0710986452987269
# goal x:  0
# goal y:  0
# left and right speeds 117 120
#
# iteration 220
# pose error 0.3494988384800163 -0.013038510318697849
# predicted x:  0.3439794542220696
# predicted y:  -0.06186738374917447
# goal x:  0
# goal y:  0
# left and right speeds 117 120
#
# iteration 221
# pose error 0.29236178779388383 -0.013001788835319772
# predicted x:  0.2876119091845206
# predicted y:  -0.05248623302610904
# goal x:  0
# goal y:  0
# left and right speeds 117 120
#
# iteration 222
# pose error 0.23522493374096587 -0.013561689394463006
# predicted x:  0.2312688033167351
# predicted y:  -0.04295940020399589
# goal x:  0
# goal y:  0
# left and right speeds 117 120
#
# iteration 223
# pose error 0.1780890173667245 -0.015172733018348428
# predicted x:  0.17495064332593482
# predicted y:  -0.03328619092787646
# goal x:  0
# goal y:  0
# left and right speeds 116 121
#
# ******************************* goal reached *******************************

# %% [markdown]
# ### 5.3 Mapping the robot's trajectory
# The following code creates a map based on the stored values for the robot's motion. This way it is possible to see where the obstacles were detected and which actions were taken to avoid them.

# %%
import matplotlib.pyplot as plt
import numpy as np

ax = plt.gca()
ax.invert_yaxis()
ax.set_aspect('equal', adjustable='box')

ct_x = control_x.copy()
ct_y = control_y.copy()

for i in range(len(control_x)):
    ct_x[i] += 0.5
    ct_y[i] += 0.5
    
plt.plot(ct_x, ct_y, linewidth = 1)

x_goals = []
y_goals = []

for goal in goal_list:
    x_goals.append(goal[1]+0.5)
    y_goals.append(goal[0]+0.5)
    
plt.scatter(x_goals, y_goals, color="r", marker="x")

ax.legend(['Control path', 'Goals'])
plt.title("PID control simulated trajectory")

plt.xticks(np.arange(0, 7, step=1))
plt.yticks(np.arange(0, 10, step=1))
plt.grid()

plt.savefig('motion_control.png', dpi=400)
plt.show()
